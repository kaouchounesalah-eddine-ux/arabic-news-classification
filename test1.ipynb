# %%
def first_10_word(text):
    return " ".join(text.split()[:10])

# %%
import pandas as pd 
from build_dataset import df

sample=df.sample(n=10,random_state=42)
df1=pd.DataFrame({
    "id":range(1,11),
    "Title":sample["Title"].values,
    "Category":sample["Category"].values,
    "Body":sample["Body"].apply(first_10_word)
})
df1
# Out:
#       id                                              Title Category  \
# 1782   1           بالفيديو: سامي سعيد يطرح ''فرصة ومناسبة"    ثقافة
# 3917   2    نجم الرجاء في لائحة المنتخب الوطني لكأس إفريقيا    رياضة
# 221    3     هذه طرق دفع التبرعات لصندوق تدبير جائحة كورونا   اقتصاد
# 2135   4           60 دولة إفريقية تطالب ترامب بـ"الاعتذار"     دولي
# 5224   5            12 عمرة لموظفات إدارة السجون لهذا السبب    مجتمع
# 1168   6  بالفيديو: هذا قائمة أشهر 5 أغانٍ عربية اقتبسها...    ثقافة
# 879    7  الجزائر تتصدر قائمة مخابئ الأموال إفريقيا.. وا...   اقتصاد
# 156    8    الأسر المغربية تودع السنة بـ350 مليار من القروض   اقتصاد
# 1657   9  بالفيديو: كونغولية تنافس حسناوات المغرب على لق...    ثقافة
# 323   10  بالصور: طرام البيضاء يعقم عرباته لمنع انتشار ف...   اقتصاد
#
#                                                    Body
# 1782  أطلق الفنان سامي سعيد أغنيته الشبابية الجديدة ...
# 3917  اختار هيرفي رونار، مدرب المنتخب الوطني، بدر با...
# ...

# %%
l=[category for category in df["Category"].sample(n=10,random_state=42)]
print(l)
# Out:
# ['ثقافة', 'رياضة', 'اقتصاد', 'دولي', 'مجتمع', 'ثقافة', 'اقتصاد', 'اقتصاد', 'ثقافة', 'اقتصاد']

# %%
print(type(df["Category"]))
# Out:
# <class 'pandas.Series'>

# %%
sample=df.sample(n=10,random_state=42)[["Title","Category"]]
print(type(sample.values))
print(type(sample))
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.DataFrame'>

# %%
import pandas as pd

data = {
    "CustomerID": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010,
                   1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1020],

    "First_Name": ["Frodo", "Abed", "Walter", "Dwight", "Jon", "Ron", "Jeff", "Sherlock",
                   "Gandalf", "Peter", "Samwise", "Harry", "Don", "Leslie", "Toby",
                   "Ron", "Michael", "Clark", "Creed", "Anakin", "Anakin"],

    "Last_Name": ["Baggins", "Nadir", "/White", "Schrute", "Snow", "Swanson", "Winger",
                  "Holmes", "", "Parker5", "Gamgee", "...Potter", "Draper", "Knope",
                  "Flenderson_", "Weasley", "Scott", "Kent", "Braton", "Skywalker",
                  "Skywalker"],

    "Phone_Number": ["123-545-5421", "123/643/9775", "7066950392", "123-543-2345",
                     "876|678|3469", "304-762-2467", "", "876|678|3469", "N/a",
                     "123-545-5421", "", "7066950392", "123-543-2345", "876|678|3469",
                     "304-762-2467", "123-545-5421", "123/643/9775", "7066950392",
                     "N/a", "876|678|3469", "876|678|3469"],

    "Address": [
        "123 Shire Lane, Shire",
        "93 West Main Street",
        "298 Drugs Driveway",
        "980 Paper Avenue, Pennsylvania, 18503",
        "123 Dragons Road",
        "768 City Parkway",
        "1209 South Street",
        "98 Clue Drive",
        "123 Middle Earth",
        "25th Main Street, New York",
        "612 Shire Lane, Shire",
        "2394 Hogwarts Avenue",
        "2039 Main Street",
        "343 City Parkway",
        "214 HR Avenue",
        "2395 Hogwarts Avenue",
        "121 Paper Avenue, Pennsylvania",
        "3498 Super Lane",
        "N/a",
        "910 Tatooine Road, Tatooine",
        "910 Tatooine Road, Tatooine"
    ],

    "Paying Customer": ["Yes", "No", "N", "Yes", "Y", "Yes", "No", "N", "Yes", "Yes",
                        "Yes", "Y", "Yes", "Yes", "N", "No", "Yes", "Y", "N/a", "Yes", "Yes"],

    "Do_Not_Contact": ["No", "Yes", "", "Y", "No", "Yes", "No", "No", "", "No",
                       "No", "", "N", "No", "No", "N", "No", "", "Yes", "N", "N"],

    "Not_Useful_Column": [True, False, True, True, True, True, False, False, False,
                          True, True, True, False, False, False, False, False, True,
                          True, True, True]
}

df = pd.DataFrame(data)

df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf                        N/a
# 9         1010      Peter      Parker5  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017    Michael        Scott  123/643/9775
# ...

# %%
df = df.drop_duplicates()

# %%
df = df.drop(columns="Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf                        N/a
# 9         1010      Peter      Parker5  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017    Michael        Scott  123/643/9775
# ...

# %%
# df["Last_Name"] = df["Last_Name"].str.(l/r)strip("1235.../")
df["Last_Name"] = df["Last_Name"].str.strip("1235.../_")
df["Last_Name"]
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: str

# %%
# df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]',"",regex=True)
df["Phone_Number"] = df["Phone_Number"].str.replace(r'\D',"",regex=True)
df["Phone_Number"]=df["Phone_Number"].apply(lambda x:x[0:3]+'-'+x[3:6]+'-'+x[6:])
df["Phone_Number"] = df["Phone_Number"].str.replace("--","")
df["Phone_Number"]
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2     706-695-0392
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6
# 7     876-678-3469
# 8
# 9     123-545-5421
# 10
# 11    706-695-0392
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17    706-695-0392
# 18
# 19    876-678-3469
# Name: Phone_Number, dtype: str

# %%
df[["Street","State","Zip"]]=df["Address"].str.split(',',n=2,expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes","Y")
df["Paying Customer"] = df["Paying Customer"].str.replace("No","N")
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes","Y")
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df = df.replace("N/a","")

df.fillna("")
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
for x in df.index:
    if df.loc[x,"Do_Not_Contact"] == "Y":
        df.drop(x,inplace = True)
for x in df.index:
    if df.loc[x,"Phone_Number"] == "":
        df.drop(x,inplace = True)

# or we can just do :
# df.dropna(subset="Phone_Number",inplace=True)

for x in df.index:
    if df.loc[x,"Do_Not_Contact"] != "N":
        df.loc[x,"Do_Not_Contact"]="N"

df
# numbers_to_call = df[df["Do_Not_Contact"] !="Y"]
# numbers_to_call=numbers_to_call[numbers_to_call["Phone_Number"]!=""]
# numbers_to_call
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White  706-695-0392
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017    Michael       Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 2               298 Drugs Driveway               N              N
# ...

# %%
df.reset_index(drop=True,inplace=True)
df[""]
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1003     Walter       White  706-695-0392
# 2         1005        Jon        Snow  876-678-3469
# 3         1008   Sherlock      Holmes  876-678-3469
# 4         1010      Peter      Parker  123-545-5421
# 5         1012      Harry      Potter  706-695-0392
# 6         1013        Don      Draper  123-543-2345
# 7         1014     Leslie       Knope  876-678-3469
# 8         1015       Toby  Flenderson  304-762-2467
# 9         1016        Ron     Weasley  123-545-5421
# 10        1017    Michael       Scott  123-643-9775
# 11        1018      Clark        Kent  706-695-0392
# 12        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 1               298 Drugs Driveway               N              N
# ...
